# %% [markdown]
# # LT218, 8500 nm

# %%
import sys
sys.path.append('../')
from classes import MKID
import functions as f
import matplotlib.pyplot as plt

# %matplotlib widget

# %% [markdown]
# ## KID 8

# %%
light_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
dark_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
LT = 218
wavelength = 8500
kid_nr = 8
pread = 114
comment = '20221025_LN2load'
chuncksize = 40
LT218_KID8_P114 = MKID(LT, wavelength, light_dir, dark_dir, kid_nr, pread, comment, chuncksize)

# %%
mkid = LT218_KID8_P114     # choose the object you want to analyze
psc = 0.15
nsc = 0.15
settings = {'sf':1e6,'coord':'smith','response':'X','pw':512,'sw':150,'window':'box','ssf':1,'buffer':0.125,'mph':psc,'mpp':psc,'noise_mph':nsc,'noise_mpp':nsc,
            'nr_noise_segments':100,'binsize':0.01,'H_range':0.4,'fit_T':[100, 300],'max_bw':10000,'tlim':[0, 1],'filter_std':5,'rise_offset':0.1}

# %%
mkid.initiate(settings,f,binsize=0.1,dpulse=10,plot_pulse=None, below=.15)

# %%
# the mkid.overview attribute does the full pulse analysis and provides an overview plot of all the relevant parameters
mkid.overview(settings, f, redo_peak_model=True, save=False, figpath='../Results/')

# %% [markdown]
# ## KID 10

# %%
light_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
dark_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
LT = 218
wavelength = 8500
kid_nr = 10
pread = 117
comment = '20221025_LN2load'
chuncksize = 40
LT218_KID10_P116 = MKID(LT, wavelength, light_dir, dark_dir, kid_nr, pread, comment, chuncksize)

# %%
mkid = LT218_KID10_P116     # choose the object you want to analyze
psc = 0.05
nsc = 0.17
settings = {'sf':1e6,'coord':'smith','response':'X','pw':512,'sw':75,'window':'box','ssf':1,'buffer':0.25,'mph':psc,'mpp':psc,'noise_mph':nsc,'noise_mpp':nsc,
            'nr_noise_segments':100,'binsize':0.04,'H_range':0.17,'fit_T':[100, 300],'max_bw':10000,'tlim':[0, 1],'filter_std':5,'rise_offset':0.1}

# %%
mkid.initiate(settings,f,binsize=0.1,dpulse=10,plot_pulse=10, below=.15)

# %%
# the mkid.overview attribute does the full pulse analysis and provides an overview plot of all the relevant parameters
mkid.overview(settings, f, redo_peak_model=True, save=True, figpath='../Results/')

# %% [markdown]
# ## KID21

# %%
light_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
dark_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
LT = 218
wavelength = 8500
kid_nr = 21
pread = 103
comment = '20221025_LN2load'
chuncksize = 40
LT218_KID21_P103 = MKID(LT, wavelength, light_dir, dark_dir, kid_nr, pread, comment, chuncksize)

# %%
mkid = LT218_KID21_P103      # choose the object you want to analyze
psc = 0.045
nsc = 0.12
settings = {'sf':1e6,'coord':'smith','response':'X','pw':256,'sw':30,'window':'box','ssf':1,'buffer':0.25,'mph':psc,'mpp':psc,'noise_mph':nsc,'noise_mpp':nsc,
            'nr_noise_segments':100,'binsize':0.02,'H_range':0.12,'fit_T':[50, 150],'max_bw':10000,'tlim':[0, 1],'filter_std':5,'rise_offset':0.1}

# %%
# the mkid.initiate attribute is for quickly checking how the pulse selection and alignment is going. It will only analyze one chunck of binfiles that was set by the initiation of the object.
mkid.initiate(settings,f,binsize=0.1,dpulse=10,plot_pulse=5, below=.1)

# %%
# the mkid.overview attribute does the full pulse analysis and provides an overview plot of all the relevant parameters
mkid.overview(settings, f, redo_peak_model=True, save=True, figpath='../Results/')

# %% [markdown]
# ## KID 24

# %%
light_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs mono off long/TD_Power" 
dark_dir = "D:/Data/LT218Chip1_BF_20221025_MIR8_5/12KIDs LN2 load - long/TD_Power" 
LT = 218
wavelength = 8500
kid_nr = 24
pread = 113
comment = '20221025_LN2load'
chuncksize = 40
LT218_KID24_P113 = MKID(LT, wavelength, light_dir, dark_dir, kid_nr, pread, comment, chuncksize)
# Out:
# 200 files obtained, chunckwise peakmodel is True with chuncksize=40

# %%
mkid = LT218_KID24_P113      # choose the object you want to analyze
psc = 0.05
nsc = 0.05
settings = {'sf':1e6,'coord':'smith','response':'X','pw':256,'sw':50,'window':'box','ssf':1,'buffer':0.125,'mph':psc,'mpp':psc,'noise_mph':nsc,'noise_mpp':nsc,
            'nr_noise_segments':100,'binsize':0.02,'H_range':0.2,'fit_T':[50, 150],'max_bw':10000,'tlim':[0, 1],'filter_std':5,'rise_offset':0.1}

# %%
# the mkid.initiate attribute is for quickly checking how the pulse selection and alignment is going. It will only analyze one chunck of binfiles that was set by the initiation of the object.
mkid.initiate(settings,f,binsize=0.1,dpulse=100,plot_pulse=None, below=.1)
# Out:
# N_det = 4099, N_sel = 3783 (=92 perc: -4 perc. too close, -4 perc. outliers)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# the mkid.overview attribute does the full pulse analysis and provides an overview plot of all the relevant parameters
mkid.overview(settings, f, redo_peak_model=False, save=True, figpath='../Results/')
# Out:
# N_det = 2933, N_sel = 2608 (=89 perc: -7 perc. too close, -4 perc. outliers)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
from scipy.optimize import curve_fit

mph = mkid.settings['mph']
sw = mkid.settings['sw']
kernel = np.ones(sw) / sw
smoothed_dark = np.convolve(mkid.dark_amp, kernel, mode='valid')
dark_sigma = np.std(smoothed_dark)

def exponetial(x, b, c, a=mph):
    return np.exp(-(x-a)/b)*c


dark_H = mkid.data['dark_H_smoothed']
darkhist, darkbins = np.histogram(dark_H, bins=30)
darkbin_centers = (darkbins[:-1] + darkbins[1:]) / 2
popt, pcov = curve_fit(exponetial, darkbin_centers, darkhist)
b = popt[0]
c = popt[1]

fig, ax = plt.subplots()
# mkid.plot_hist(ax, 'smoothed', 0.01)
H = mkid.data['H_smoothed']
hist, bins = np.histogram(H, bins=100)
bin_centers = (bins[:-1] + bins[1:]) / 2
_ = ax.hist(H, bins=100, alpha=0.5, facecolor='tab:orange')
_ = ax.hist(dark_H, bins=30, facecolor='k')
ax.axvline(mph, 0, 1, lw=1, c='k', label='mph=%.2f' % (mph))
ax.plot(darkbin_centers, exponetial(darkbin_centers, b, np.amax(darkhist)), c='r', lw=1, ls='--', label='$y_1$: $b_1=%.1e$, $c_1=%d$' % (b, np.amax(darkhist)))
ax.plot(bin_centers, exponetial(bin_centers, b, np.amax(hist)), c='r', lw=1, ls='-.', label='$y_2$: $b_2=b_1$, $c_2=%d$' % (np.amax(hist)))
ax.axvline(5*dark_sigma, 0, 1, lw=1, label='$H_{range}=>5\sigma_{dark}=%.2f$' % (5*dark_sigma), c='r')
ax.annotate('$y=c\\cdot e^{-\\frac{x-mph}{b}}$', (.5, .5), xycoords='figure fraction', fontsize=18, c='r')
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plotting to MKIDs

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, ax = plt.subplot_mosaic('ab', constrained_layout=True)
LT218_KID21_P103.plot_mean_pulse(ax['a'], 'lin')
LT218_KID10_P116.plot_mean_pulse(ax['a'], 'lin') 
LT218_KID21_P103.plot_psd_noise(ax['b'])
LT218_KID10_P116.plot_psd_noise(ax['b']) 
ax['b'].legend(['KID21', 'KID10'])
